# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from d2l import torch as d2l
from sklearn.metrics.cluster import  mutual_info_score
import numpy as np
df = pd.read_csv("RNNLOSS.csv")
df
# Out:
#       Wall time  Step       Value      Loss
# 0    1673085325     0  543.637695  8.041291
# 1    1673085326     1  467.487457  6.151539
# 2    1673085327     2  440.076416  6.163097
# 3    1673085327     3  481.377045  6.222167
# 4    1673085328     4  493.659149  6.168244
# ..          ...   ...         ...       ...
# 495  1673085663   495    1.487486  0.901040
# 496  1673085664   496    1.470380  0.733172
# 497  1673085664   497    1.431545  0.452811
# 498  1673085665   498    1.519702  0.526013
# 499  1673085666   499    1.457263  0.548858
#
# [500 rows x 4 columns]

# %%
df.iloc[:, 2:].plot.line()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from d2l import torch as d2l
from sklearn.metrics.cluster import  mutual_info_score
import numpy as np
df = pd.read_csv("RNNLOSS.csv")
df
